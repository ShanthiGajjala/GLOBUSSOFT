# %% [markdown]
# Task - 1
# To write a script to scrape the data from amazon.in along with suitable information of products and store in a csv file.
# Script should get all the details for the laptop i.e.
# • Image
# • Title
# • Rating
# • Price
# • Ad / Organic Result
# Task 1 Submission:
# • Have to save a file either in .py or .ipynb form.
# • Output file should be saved with timestamp.

# %% [markdown]
# Step 1: Import Libraries

# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\shant\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\shant\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\shant\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shant\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shant\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shant\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shant\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shant\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\shant\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shant\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shant\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shant\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\shant\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime

# %% [markdown]
# Step 2: Define Amazon Search URL + Add Headers

# %%
url = "https://www.amazon.in/s?k=laptop"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept-Language": "en-US,en;q=0.5"
}

# %% [markdown]
# Step 3: Send Request & Parse HTML

# %%
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# Step 4: Extract All Laptop Products

# %%
products = soup.find_all("div", {"data-component-type": "s-search-result"})
len(products)
# Out:
# 22

# %% [markdown]
# Step 5: Extract Details for Each Product

# %%
data = []

for item in products:
    
    # Image
    image_tag = item.find("img", class_="s-image")
    image = image_tag["src"] if image_tag else None

    # Title
    title_tag = item.h2
    title = title_tag.text.strip() if title_tag else None

    # Rating
    rating_tag = item.find("span", class_="a-icon-alt")
    rating = rating_tag.text.strip() if rating_tag else None

    # Price
    price_tag = item.find("span", class_="a-offscreen")
    price = price_tag.text.strip() if price_tag else None

    # Ad / Organic
    ad_tag = item.find("span", string="Sponsored")
    result_type = "Ad" if ad_tag else "Organic"

    # Add to list
    data.append({
        "Image": image,
        "Title": title,
        "Rating": rating,
        "Price": price,
        "Ad/Organic": result_type
    })

data[:5]   # preview first 5 items
# Out:
# [{'Image': 'https://m.media-amazon.com/images/I/71Z4mSII9BL._AC_UY218_.jpg',
#   'Title': "HP 15, 13th Gen Intel Core i5-1334U, (16GB DDR4,512GB SSD) Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0577TU, Iris Xe, FHD Camera w/Shutter Laptop",
#   'Rating': '3.8 out of 5 stars',
#   'Price': '₹52,490',
#   'Ad/Organic': 'Ad'},
#  {'Image': 'https://m.media-amazon.com/images/I/71ueiAj0ZfL._AC_UY218_.jpg',
#   'Title': 'ASUS Zenbook S16, 16" Touch Screen, 3K OLED, AMD Ryzen AI 7 Octa Core 350,Copilot+ AI PC (24GB/1TB/AMD Radeon iGPU/Windows 11/M365 Basic (1Year)*/Office Home 2024/Zumaia Gray/1.5 Kg), UM5606KA-RJ109WS',
#   'Rating': '3.7 out of 5 stars',
#   'Price': '₹1,27,812',
#   'Ad/Organic': 'Ad'},
#  {'Image': 'https://m.media-amazon.com/images/I/71h+7L8gcrL._AC_UY218_.jpg',
#   'Title': 'BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey',
#   'Rating': '3.1 out of 5 stars',
#   'Price': '₹12,090',
#   'Ad/Organic': 'Organic'},
#  {'Image': 'https://m.media-amazon.com/images/I/61o8UTGgcFL._AC_UY218_.jpg',
#   'Title': 'HP 255 G10 Laptop for Home or Work, 16GB RAM, 512GB SSD, 15.6" Full HD, Ryzen 3 7330U (Beats Intel i5-1135G7), HDMI, USB-C, Windows 11 Pro, Business and Fun Ready',
#   'Rating': '4.4 out of 5 stars',
#   'Price': '₹33,490',
#   'Ad/Organic': 'Organic'},
#  {'Image': 'https://m.media-amazon.com/images/I/61bRpOLNVKL._AC_UY218_.jpg',
#   'Title': 'HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop',
#   'Rating': '5.0 out of 5 stars',
#   'Price': '₹24,999',
#   'Ad/Organic': 'Organic'}]

# %% [markdown]
# Step 6: Convert to DataFrame & Save with Timestamp

# %%
df = pd.DataFrame(data)

timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"amazon_laptops_{timestamp}.csv"

df.to_csv(filename, index=False)

filename
# Out:
# 'amazon_laptops_20251127_101719.csv'

# %%
amazon= pd.read_csv('amazon_laptops_20251125_105712.csv') # read the datset 
amazon
# Out:
#                                                 Image  \
# 0   https://m.media-amazon.com/images/I/71ueiAj0Zf...
# 1   https://m.media-amazon.com/images/I/71dyfY6G0a...
# 2   https://m.media-amazon.com/images/I/71h+7L8gcr...
# 3   https://m.media-amazon.com/images/I/61o8UTGgcF...
# 4   https://m.media-amazon.com/images/I/81eLpuK0Yc...
# 5   https://m.media-amazon.com/images/I/61IDcxw27+...
# 6   https://m.media-amazon.com/images/I/61Y8j1QN5Y...
# 7   https://m.media-amazon.com/images/I/61Y8j1QN5Y...
# 8   https://m.media-amazon.com/images/I/617GQ0W6fx...
# 9   https://m.media-amazon.com/images/I/61Kfqt-h5-...
# 10  https://m.media-amazon.com/images/I/71bDJ9wxxW...
# 11  https://m.media-amazon.com/images/I/71yDoO9cVQ...
# 12  https://m.media-amazon.com/images/I/713cu-sW3T...
# 13  https://m.media-amazon.com/images/I/71t65q+JsL...
# 14  https://m.media-amazon.com/images/I/81LbQEPiFn...
# 15  https://m.media-amazon.com/images/I/71JcEk00fq...
# 16  https://m.media-amazon.com/images/I/71+gQ9gOTu...
# 17  https://m.media-amazon.com/images/I/71FXHAM+jW...
# 18  https://m.media-amazon.com/images/I/61QY1NrWQB...
# 19  https://m.media-amazon.com/images/I/71bagLp2sX...
# 20  https://m.media-amazon.com/images/I/71Z4mSII9B...
# 21  https://m.media-amazon.com/images/I/71ZwxyBfzE...
#
#                                                 Title              Rating  \
# 0   ASUS Zenbook S16, 16" Touch Screen, 3K OLED, A...  3.7 out of 5 stars
# 1   HP 15, Intel Core Ultra 5 125H (16GB DDR5, 1TB...  3.9 out of 5 stars
# 2   BrowseBook 14.1" FHD IPS Laptop | Best Student...  3.1 out of 5 stars
# 3   HP 255 G10 Laptop for Home or Work, 16GB RAM, ...  4.3 out of 5 stars
# 4   Ultimus APEX Bold N Intel Pentium Quad Core La...  4.2 out of 5 stars
# 5   JioBook 11 with Lifetime Office | Android 4G L...  3.0 out of 5 stars
# 6   Acer Aspire 3, Intel Core Celeron N4500, 12GB ...  3.4 out of 5 stars
# 7   Acer Aspire 3, Intel Celeron N4500, 12 GB RAM,...  3.4 out of 5 stars
# 8   HP 15, 13th Gen Intel Core i3-1315U Laptop (8G...  4.1 out of 5 stars
# 9   Dell 15, AMD Ryzen 3 7320U Processor (8GB RAM ...  4.0 out of 5 stars
# 10  Lenovo IdeaPad 1 Intel Celeron N4500, 8GB RAM,...  3.8 out of 5 stars
# 11  ASUS Vivobook Go 15, Intel Celeron N4500, Fing...  2.5 out of 5 stars
# 12  Primebook 2 Neo 2025 (New Launch) | 6GB RAM, 1...  4.5 out of 5 stars
# 13  Lenovo V15 G4 IRU 15.6" FHD 13th Gen Laptop, I...  4.3 out of 5 stars
# 14  Acer One 11 Intel Celeron N4500 (Windows 11 Ho...  2.8 out of 5 stars
# 15  HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD)...  4.0 out of 5 stars
# 16  HP 15s, 12th Gen Intel Core i3-1215U (8GB DDR4...  4.0 out of 5 stars
# 17  HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4...  4.0 out of 5 stars
# 18  Lenovo {SmartChoice)Chromebook Intel Celeron N...  3.8 out of 5 stars
# 19  HP 15, 13th Gen Intel Core i5-1334U Laptop (12...  3.8 out of 5 stars
# 20  HP 15, 13th Gen Intel Core i5-1334U, (16GB DDR...  3.8 out of 5 stars
# 21  BrowseBook 15.6" FHD IPS Laptop | Best Student...  3.1 out of 5 stars
#
#         Price Ad/Organic
# 0   ₹1,27,812         Ad
# 1     ₹64,990         Ad
# 2     ₹12,090    Organic
# 3     ₹32,999    Organic
# 4     ₹16,490    Organic
# 5     ₹12,490    Organic
# 6     ₹23,990    Organic
# 7     ₹21,990    Organic
# 8     ₹36,990    Organic
# 9     ₹29,990    Organic
# 10    ₹25,990         Ad
# 11    ₹24,900         Ad
# 12    ₹14,990    Organic
# 13    ₹58,999    Organic
# 14    ₹19,999    Organic
# 15    ₹30,990    Organic
# 16    ₹32,990    Organic
# 17    ₹37,990    Organic
# 18    ₹14,990    Organic
# 19    ₹49,280    Organic
# 20    ₹52,490         Ad
# 21    ₹16,990         Ad
